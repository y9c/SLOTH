# %%
from ete3 import Tree
import pandas as pd

# %%
pd.read_csv("./GSE81713_fish_ADR1_PHYLIP_MIX_gte5_input.annotations.txt", sep="\t")
# Out:
#       taxa         sample  count  proportion  \
# 0       N0       7B_Brain   5441    0.164859
# 1       N1       7B_Brain   4802    0.145498
# 2       N2       7B_Brain   3003    0.090989
# 3       N3       7B_Brain   2958    0.089625
# 4       N4       7B_Brain   1506    0.045631
# ..     ...            ...    ...         ...
# 596  N1721  7B_Heart_GFP+      9    0.007860
# 597  N1722  7B_Heart_GFP+      9    0.007860
# 598  N1723  7B_Heart_GFP+      6    0.005240
# 599  N1724  7B_Heart_GFP+      5    0.004367
# 600  N1725  7B_Heart_GFP+      5    0.004367
#
#                                                  event
# 0    12D+136_46D+157_46D+157_98D+210_98D+210_98D+21...
# 1    7D+135_9D+160_NONE_5D+220_44D+230_44D+230_21D+...
# 2    38D+140_38D+140_47D+184_47D+184_NONE_27D+276_2...
# 3    23I+140+TGGAGTCGAGAGCGCGCTCGTCG_NONE_NONE_144D...
# 4    38D+140_38D+140_47D+184_47D+184_54D+247_54D+24...
# ..                                                 ...
# ...

# %%
t = Tree("./GSE81713_fish_ADR1_PHYLIP_MIX_gte5_output.newick.txt", format=1)

# %%
t.get_leaves()
# Out:
# 60100

# %%
print(((t.get_leaves()[0]).up.get_children()[1]).up.up.up.get_ascii(show_internal=True, attributes=["name", "dist"]))
# Out:
#                /-N1720, 1.0
#               |
#           /, 1.0         /-N1723, 1.0
#          |    |     /, 1.0
#          |    |    |     \-N775, 1.0
#          |     \, 1.0
#      /, 1.0        |     /-N758, 1.0
#     |    |          \, 1.0
#     |    |               \-N440, 1.0
#     |    |
#     |     \-N101, 1.0
#     |
#     |               /-N788, 1.0
#     |              |
#     |          /, 1.0         /-N765, 1.0
# -, 1.0        |    |     /, 1.0
#     |         |    |    |     \-N125, 1.0
#     |         |     \, 1.0
#     |     /, 1.0        |     /-N752, 1.0
#     |    |    |          \, 1.0
#     |    |    |               \-N106, 1.0
#     |    |    |
#     |    |    |     /-N762, 1.0
#     |    |     \, 1.0
#     |    |         |     /-N145, 1.0
#      \, 1.0         \, 1.0
#          |               \-N83, 1.0
#          |
#          |          /-N599, 1.0
#          |     /, 1.0
#          |    |     \-N107, 1.0
#          |    |
# ...
